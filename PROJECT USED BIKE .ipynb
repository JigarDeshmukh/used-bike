# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #  READ &CLEANING OF DATA AND FORMATTING IT PROPERLY

# %%
data=pd.read_csv("usedbikedata")

# %%
data   #here there is unnamed :0 columns
# Out:
#      Unnamed: 0                             bike_name     price       city  \
# 0             0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad
# 1             1           Royal Enfield Classic 350cc  119900.0      Delhi
# 2             2                  Triumph Daytona 675R  600000.0      Delhi
# 3             3                  TVS Apache RTR 180cc   65000.0  Bangalore
# 4             4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore
# ..          ...                                   ...       ...        ...
# 495         495                  Bajaj Discover 135cc   13600.0      Delhi
# 496         496                  TVS Apache RTR 180cc   73000.0     Rohtak
# 497         497                  Bajaj Discover 125cc   17000.0  Bangalore
# 498         498                  Bajaj Discover 150cc   29000.0    Gurgaon
# 499         499                Suzuki Gixxer SF 150cc   49000.0      Delhi
#
#      kms_driven         owner   age  power          brand
# ...

# %%
data.rename(columns={'Unnamed: 0':"Sr_no"},inplace=True)  #renaming done of (unnamed:0) to sr_no

# %%
data.head()
# Out:
#    Sr_no                             bike_name     price       city  \
# 0      0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad
# 1      1           Royal Enfield Classic 350cc  119900.0      Delhi
# 2      2                  Triumph Daytona 675R  600000.0      Delhi
# 3      3                  TVS Apache RTR 180cc   65000.0  Bangalore
# 4      4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore
#
#    kms_driven        owner  age  power          brand
# 0     17654.0  First Owner  3.0  110.0            TVS
# 1     11000.0  First Owner  4.0  350.0  Royal Enfield
# 2       110.0  First Owner  8.0  675.0        Triumph
# 3     16329.0  First Owner  4.0  180.0            TVS
# 4     10000.0  First Owner  3.0  150.0         Yamaha

# %%
data.set_index('Sr_no',inplace=True) # changing  index no by using set_index

# %%
data.head()
# Out:
#                                   bike_name     price       city  kms_driven  \
# Sr_no
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#              owner  age  power          brand
# Sr_no
# 0      First Owner  3.0  110.0            TVS
# 1      First Owner  4.0  350.0  Royal Enfield
# 2      First Owner  8.0  675.0        Triumph
# 3      First Owner  4.0  180.0            TVS
# 4      First Owner  3.0  150.0         Yamaha

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   500 non-null    object
#  1   price       500 non-null    float64
#  2   city        500 non-null    object
#  3   kms_driven  500 non-null    float64
#  4   owner       500 non-null    object
#  5   age         500 non-null    float64
#  6   power       500 non-null    float64
#  7   brand       500 non-null    object
# dtypes: float64(4), object(4)
# memory usage: 35.2+ KB

# %%
data.describe()
# Out:
#               price     kms_driven         age        power
# count  5.000000e+02     500.000000  500.000000   500.000000
# mean   1.120430e+05   18719.968000    5.342000   260.662000
# std    1.601634e+05   21830.002314    3.061991   191.864389
# min    9.350000e+03       3.000000    1.000000   100.000000
# 25%    4.500000e+04    7775.250000    3.000000   150.000000
# 50%    7.500000e+04   15000.000000    5.000000   200.000000
# 75%    1.152500e+05   24688.250000    7.000000   350.000000
# max    1.900000e+06  357000.000000   39.000000  1800.000000

# %% [markdown]
# # FINDING THE TOTAL COUNT OF  BRAND  | WHICH BRAND HAS MORE DEMAND IN RESALE MARKET

# %%
plt.figure(figsize=(10,10))
data['brand'].value_counts().plot(kind='bar')
plt.title("BIKE BRAND")
plt.ylabel("NO of bike")
plt.xlabel("BRAND")
plt.xticks(rotation=90)
plt.show()

# %%
data.value_counts("brand") #finding which brand has more bike in resale market
# Out:
# brand
# Bajaj              141
# Royal Enfield      106
# Hero                48
# Yamaha              40
# Honda               39
# KTM                 33
# TVS                 29
# Suzuki              24
# Benelli              8
# Harley-Davidson      7
# Ducati               5
# Kawasaki             5
# Mahindra             4
# Hyosung              3
# Triumph              3
# BMW                  2
# Jawa                 2
# Indian               1
# dtype: int64

# %% [markdown]
# # TOTAL NUMBER OF BIKE IN LIST WITH BIKE NAME

# %%
plt.figure(figsize=(50,50))
data['bike_name'].value_counts().plot(kind="barh") # pandas plot
plt.title("Bike Brand")
plt.ylabel("brand")
plt.xlabel("count")
plt.xticks(rotation=90)
plt.show()

# %%
data.value_counts("bike_name")   # for quick overview
# Out:
# bike_name
# Royal Enfield Classic 350cc        40
# Bajaj V15 150cc                    15
# Royal Enfield Thunderbird 350cc    15
# Bajaj Pulsar NS200                 14
# Bajaj Pulsar 220cc                 14
#                                    ..
# Honda CB Hornet 160R CBS            1
# Honda CB Hornet 160R  ABS DLX       1
# Hero Xpulse 200T                    1
# Hero Splendor plus 100cc            1
# Yamaha YZF-R3 320cc ABS             1
# Length: 188, dtype: int64

# %%
data.value_counts("bike_name").idxmax()
# Out:
# 'Royal Enfield Classic 350cc'

# %%
data.value_counts("bike_name").idxmin()
# Out:
# 'Yamaha YZF R6 600cc'

# %% [markdown]
# ## NOW WE WILL SEE OWNER DETAILS

# %%
#seeing owner in market
plt.figure(figsize=(5,5))
data["owner"].value_counts().plot.pie(autopct="%1.2f%%")
plt.title("OWNER ")
plt.show()

# %%
#in this scenario we are using seaborn
sns.set(style="darkgrid")
a=sns.countplot(x = "owner", data = data)

# %% [markdown]
# ## BIKE IN CITY

# %%
plt.figure(figsize=(100,100))         #chart give view of city with number of bikes
sns.countplot(data=data, x="city")
plt.show()

# %%
data["city"].value_counts()
# Out:
# Delhi        156
# Bangalore     93
# Mumbai        50
# Hyderabad     21
# Chennai       13
#             ...
# Kochi          1
# Vidisha        1
# Unnao          1
# Thrissur       1
# Bikaner        1
# Name: city, Length: 85, dtype: int64

# %%
data.value_counts("city").idxmax()
# Out:
# 'Delhi'

# %%
city= data[data['city'] == 'Delhi'].sort_values(by ='owner')   #hunting for top city
city
# Out:
#                              bike_name     price   city  kms_driven  \
# Sr_no
# 1          Royal Enfield Classic 350cc  119900.0  Delhi     11000.0
# 352                 Honda CBR 250R ABS   85000.0  Delhi     15000.0
# 355           Honda CB Hornet 160R STD   42000.0  Delhi     19000.0
# 357        Royal Enfield Classic 350cc   87000.0  Delhi     15000.0
# 358        Royal Enfield Classic 350cc  102500.0  Delhi     29000.0
# ...                                ...       ...    ...         ...
# 426               TVS Apache RTR 180cc   40000.0  Delhi     16688.0
# 336         Harley-Davidson Street 750  417000.0  Delhi     13000.0
# 434    Royal Enfield Thunderbird 350cc   74500.0  Delhi      5432.0
# 226           Bajaj Avenger Street 220   45400.0  Delhi     23000.0
# 265                 Yamaha SZ-RR 150cc   23600.0  Delhi     22672.0
#
#               owner  age  power            brand
# Sr_no
# 1       First Owner  4.0  350.0    Royal Enfield
# ...

# %% [markdown]
# ## Below are the bike used in DELHI

# %%
city= data[data['city'] =='Delhi']['bike_name'].unique()   #hunting for top city and bike in the city
city
# Out:
# array(['Royal Enfield Classic 350cc', 'Triumph Daytona 675R',
#        'Yamaha FZs 150cc', 'Honda CB Hornet 160R  ABS DLX',
#        'Hero Splendor Plus Self Alloy 100cc',
#        'Royal Enfield Classic Desert Storm 500cc', 'Bajaj Discover 100M',
#        'Bajaj Discover 125M', 'Hero Splendor iSmart Plus IBS 110cc',
#        'Yamaha FZ V 2.0 150cc', 'Bajaj Pulsar NS200',
#        'Suzuki Gixxer SF Fi 150cc SP ABS',
#        'Royal Enfield\u200e Bullet 350cc',
#        'Royal Enfield Bullet Electra 350cc', 'Bajaj Pulsar 220cc',
#        'Royal Enfield Thunderbird 350cc', 'Bajaj Pulsar 135LS',
#        'Hero Splendor plus 100cc', 'Honda CBR 250R', 'Hyosung GT650R',
#        'Yamaha YZF-R15 S 150cc', 'TVS Apache RTR 160 4V Disc',
#        'Honda CB ShineSP 125cc', 'Royal Enfield Electra 350cc',
#        'KTM Duke 200cc', 'TVS Apache RTR 160cc',
#        'Yamaha YZF-R15 2.0 150cc', 'Yamaha YZF-R15 V3 150cc',
#        'Bajaj Pulsar NS 200', 'Hero Super Splendor 125cc',
# ...

# %%
group=data.groupby(["city","bike_name"]).sum()     #showing city and their bike details
group
# Out:
#                                              price  kms_driven   age  power
# city          bike_name
# 24 Pargana    Yamaha Fazer 25 250cc        80400.0      5100.0   4.0  250.0
# Adoni         KTM RC 200cc                150000.0      9000.0   4.0  200.0
# Agra          Hero CD Deluxe 100cc         12200.0     46643.0  14.0  100.0
# Ahmedabad     Bajaj Avenger 220cc          40000.0     64000.0   7.0  220.0
#               Bajaj Discover 100M          25000.0     33000.0   7.0  100.0
# ...                                            ...         ...   ...    ...
# Vadodara      Suzuki Gixxer Fi 150cc ABS   96700.0      5100.0   1.0  150.0
# Varanasi      Bajaj Discover 100M          29300.0     19000.0   6.0  100.0
# Vidisha       Yamaha SZ 150cc              25000.0    172082.0   9.0  150.0
# Visakhapatnam Bajaj Pulsar 150cc           35000.0     44480.0  13.0  150.0
# Wardha        Suzuki Gixxer 150cc          80999.0      4000.0   3.0  150.0
#
# [356 rows x 4 columns]

# %% [markdown]
# ## FINDING THE CORRELATION

# %%
corr=data.corr()
corr
# Out:
#                price  kms_driven       age     power
# price       1.000000   -0.224198 -0.200896  0.873877
# kms_driven -0.224198    1.000000  0.328679 -0.197019
# age        -0.200896    0.328679  1.000000 -0.087234
# power       0.873877   -0.197019 -0.087234  1.000000

# %%
data["power"].value_counts()   #overview of horspower of bike in list and their count
# Out:
# 150.0     100
# 350.0      83
# 200.0      56
# 220.0      35
# 125.0      34
# 100.0      33
# 160.0      21
# 110.0      20
# 250.0      16
# 400.0      12
# 500.0      11
# 390.0      10
# 180.0       9
# 410.0       8
# 650.0       7
# 223.0       6
# 750.0       6
# 300.0       4
# 135.0       4
# 600.0       3
# 302.0       2
# 295.0       2
# 310.0       2
# 675.0       2
# 1300.0      2
# 959.0       1
# 899.0       1
# 1800.0      1
# 1100.0      1
# 535.0       1
# 900.0       1
# 821.0       1
# 1198.0      1
# 1299.0      1
# 883.0       1
# 765.0       1
# 320.0       1
# Name: power, dtype: int64

# %%
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=data,x=data.power,y=data.price)
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=data,x=data.brand,y=data.price,hue="power")
plt.plot()
# Out:
# []

# %% [markdown]
# ## NOW COUNTING BIKE ACCORDING TO AGE

# %%
plt.figure(figsize=(10,10))         #bike in market according to ages or usage
sns.countplot(data=data,x=data.age)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
age=data[data["age"]==4.0].sort_values(by="brand",ascending=False)   #bike with 4 year age
age.head()
# Out:
#                       bike_name     price        city  kms_driven  \
# Sr_no
# 489     Yamaha FZ S V 2.0 150cc   65000.0       Unnao     33000.0
# 221    Yamaha YZF-R15 2.0 150cc  100000.0   Hyderabad      4800.0
# 11            Yamaha FZ25 250cc   95000.0   Bangalore      9665.0
# 303       Yamaha Fazer 25 250cc   80400.0  24 Pargana      5100.0
# 31     Yamaha YZF-R15 2.0 150cc   80000.0     Kaithal     20000.0
#
#               owner  age  power   brand
# Sr_no
# 489     First Owner  4.0  150.0  Yamaha
# 221     First Owner  4.0  150.0  Yamaha
# 11      First Owner  4.0  250.0  Yamaha
# 303    Second Owner  4.0  250.0  Yamaha
# 31     Second Owner  4.0  150.0  Yamaha

# %%
age= data[data['age'] == 4.0]['bike_name'].unique()   #hunting for top city
age
# Out:
# array(['Royal Enfield Classic 350cc', 'TVS Apache RTR 180cc',
#        'Yamaha FZ25 250cc', 'Bajaj Pulsar NS200',
#        'Yamaha YZF-R15 2.0 150cc', 'KTM RC 390cc', 'KTM Duke 200cc',
#        'Royal Enfield Thunderbird 350cc', 'KTM Duke 250cc',
#        'Royal Enfield Himalayan 410cc', 'Bajaj V15 150cc',
#        'Benelli TNT 600i', 'Honda CBR 150R 150cc', 'Hyosung GT650R',
#        'Bajaj Pulsar RS200 ABS', 'Hero Passion Pro 100cc',
#        'Bajaj Avenger Street 220',
#        'Suzuki Gixxer SF 150cc Special MOTOGP Edition Rear Disc',
#        'Bajaj Pulsar 220cc', 'Royal Enfield Bullet Electra 350cc',
#        'TVS Apache RTR 200 4V FI', 'Royal Enfield Bullet Twinspark 350cc',
#        'Bajaj Dominar 400', 'Bajaj Platina  Alloy ES-100cc',
#        'Royal Enfield Classic 350cc-Redditch Edition',
#        'Hero Splendor iSmart 110cc', 'Bajaj Dominar 400 ABS',
#        'Suzuki Gixxer SF 150cc SP Rear Disc', 'Bajaj V12 125cc',
# ...

# %%
age=data[data["age"]==4.0].sort_values(by="brand",ascending=False)
age.tail()
# Out:
#                    bike_name     price       city  kms_driven        owner  \
# Sr_no
# 302          Bajaj V15 150cc   45000.0   Jabalpur      7000.0  First Owner
# 319       Bajaj Pulsar NS200   86200.0  Bangalore      9300.0  First Owner
# 337    Bajaj Dominar 400 ABS  105000.0    Chennai     20500.0  First Owner
# 402        Bajaj Pulsar 220F   74500.0      Delhi     10000.0  First Owner
# 494    Bajaj Dominar 400 ABS  140000.0     Mumbai     10200.0  First Owner
#
#        age  power  brand
# Sr_no
# 302    4.0  150.0  Bajaj
# 319    4.0  200.0  Bajaj
# 337    4.0  400.0  Bajaj
# 402    4.0  220.0  Bajaj
# 494    4.0  400.0  Bajaj

# %%
age=data[data["age"]==39.0].sort_values(by="brand",ascending=False)  #bike in market for 39 year
age.head()
# Out:
#                          bike_name     price       city  kms_driven  \
# Sr_no
# 334    Royal Enfield Bullet 350 cc  125000.0  Hyderabad     16500.0
#
#              owner   age  power          brand
# Sr_no
# 334    First Owner  39.0  350.0  Royal Enfield

# %% [markdown]
# ## NOW CALCULATING THE PRICE AND WHICH BRAND HAS BIKE IN THAT PRICE RANGE

# %%
group=data.groupby(["price","brand"]).mean()    #bike brand at which price available
group
# Out:
#                     kms_driven   age   power
# price     brand
# 9350.0    TVS          39822.0  13.0   150.0
# 10000.0   Hero         21389.0  12.0   150.0
# 10200.0   TVS          71474.0  12.0   150.0
# 11100.0   Bajaj        12000.0  12.0   150.0
# 12200.0   Hero         46643.0  14.0   100.0
# ...                        ...   ...     ...
# 885000.0  Ducati         300.0   2.0   959.0
# 935000.0  Kawasaki      2500.0   2.0   900.0
# 950000.0  Suzuki         312.0   3.0  1300.0
# 1350000.0 Ducati         190.0   1.0  1100.0
# 1900000.0 Indian        1700.0   6.0  1800.0
#
# [357 rows x 3 columns]

# %% [markdown]
# ## bike and owner details

# %%
group=data.groupby(["owner","brand"]).sum()     #showing owner and their bike details
group
# Out:
#                                    price  kms_driven    age    power
# owner        brand
# First Owner  BMW                510000.0      4400.0    6.0    620.0
#              Bajaj             8340737.0   2665984.0  689.0  25985.0
#              Benelli           2090400.0     58009.0   27.0   2701.0
#              Ducati            4335000.0     16593.0   17.0   5377.0
#              Harley-Davidson   1960000.0     18200.0   28.0   3750.0
#              Hero              1725684.0    908538.0  275.0   5780.0
#              Honda             1776087.0    498725.0  176.0   4695.0
#              Hyosung            555000.0     15300.0    9.0    900.0
#              Indian            1900000.0      1700.0    6.0   1800.0
#              Jawa               385000.0      3900.0    4.0    590.0
#              KTM               4459518.0    348711.0  127.0   7750.0
#              Kawasaki          2155000.0     21580.0   15.0   2850.0
# ...

# %% [markdown]
# ## USING PAIR PLOT TO SHOW THE RELATION BETWEEN ALL VARIABLE

# %%
sns.pairplot(data)

# %% [markdown]
# ## REASON TO TAKE  THIS DATA SET

# %% [markdown]
# 1]As coming to indian economy 6.7%  people are under poverty ratio and they cant afford to buy new bikes as this data can give idea or knowledge to the people about which bike brand or bike is suitable to them
# 2] Normal people buy bike for there daily usage and they prefer for used bikes

# %% [markdown]
# # CONCLUSION
# 1] Brand having more demand in resale market--> Bajaj,Royal Enfield,Hero,Yamaha,Honda
# 2] Bike with highest count in market-->Royal Enfield Classic 350cc
# 3] Owner in market-->FIRST OWNER(91%),SECOND OWNER(7.80),THIRD OWNER(1%)
# 4] Bike power to price relation as power increace the price increase
# 5] Bike in cities -->(Delhi-156,Bangalore-93,Mumbai-50,Hyderabad-21,Chennai-13)
# 6] Bike in Market after there production- bike to resale after 4 year are -->(Yamaha FZ S V 2.0 150cc,Yamaha FZ25 250cc) etc...... and (Royal Enfield Bullet 350 cc) to resale after 39 years
# 7] Bikes range -->TVS Bikes has bike in range (9350,10200 rs etc)

# %% [markdown]
# #                                                                                                                                                                                      THANKYOU
